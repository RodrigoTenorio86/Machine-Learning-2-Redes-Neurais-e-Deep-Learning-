# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoTenorio86/Machine-Learning-2-Redes-Neurais-e-Deep-Learning-/blob/master/Funcoes_de_Ativacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funçoes de Ativação

# %% [markdown]
# ### Sigmoide

# %%
import matplotlib.pylab as plt

# %%
import numpy as np

# %%
x = np.arange(-8,8,0.1)

# %%
f=1/ (1+np.exp(-x))

##grafico

plt.plot(x,f)
plt.xlabel("x")
plt.ylabel("f(x) ")
plt.show()

# %%
w1= 0.5
w2 = 1
w3 = 2.0

l1 =  "w=0.5"
l2 =  "w=1.0"
l3 =  "w=2.0"

for w, l in[(w1,l1),(w2,l2),(w3,l3)]:
    f = 1 / (1+np.exp(-x*w))
    plt.plot(x, f, label=l)

plt.xlabel("x")
plt.ylabel("h_w(x)")
plt.legend(loc=2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
w = 5.0
b1 = -8.0
b2 = 0
b3 = 8.0

l1= 'b = -8.0'
l2= 'b = 0.0'
l3= 'b = 8.0'

for b, l in [(b1,l1),(b2,l2),(b3,l3)]:
    f= 1 / (1 + np.exp(-x*w+b))
    plt.plot(x, f, label = l)

plt.xlabel("x")
plt.ylabel("h_wb(x)")
plt.legend(loc=2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
from tensorflow import keras

# %% [markdown]
# Preditor: -1 0 1 2 3 4
# Predito: -2 1 4 7 10 13
#
# predito: =1 + 3 * Preditor

# %%
modelo = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
modelo.compile(optimizer="sgd",loss="mean_squared_error")

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype = float)

# %%
modelo.fit(xs,ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 57.7534
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 45.4377
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 35.7482
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 28.1250
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 22.1274
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 17.4088
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 13.6965
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 10.7757
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4779
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6700
# Epoch 11/500
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2477
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1286
# ...

# %%
print(modelo.predict([10.0]))
# Out:
# [[31.00023]]

# %%
print(modelo.predict([4.0]))
# Out:
# [[13.0000305]]

# %% [markdown]
# ##Nova Base de Dados
#
# X: 12 , 25 ,36 ,48 ,54 ,78
# Y: 5, 11.5, 17, 23, 26, 36

# %%
modelo1 = tf.keras.Sequential([keras.layers.Dense(units=4,input_shape=[1])])
modelo = tf.keras.Sequential([keras.layers.Dense(units=4, input_shape=[1])])

# %%
modelo1.compile(optimizer="sgd",loss="mean_squared_error")
xs = np.array([12 , 25 ,36 ,48 ,54], dtype = float)
ys = np.array([5, 11.5, 17, 23, 26], dtype = float)
modelo1.fit(xs,ys, epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 2ms/step - loss: 119.2623
# Epoch 2/50
# 1/1 [==============================] - 0s 1ms/step - loss: 4711.2178
# Epoch 3/50
# 1/1 [==============================] - 0s 2ms/step - loss: 186341.8750
# Epoch 4/50
# 1/1 [==============================] - 0s 2ms/step - loss: 7370577.5000
# Epoch 5/50
# 1/1 [==============================] - 0s 2ms/step - loss: 291536480.0000
# Epoch 6/50
# 1/1 [==============================] - 0s 2ms/step - loss: 11531459584.0000
# Epoch 7/50
# 1/1 [==============================] - 0s 2ms/step - loss: 456116404224.0000
# Epoch 8/50
# 1/1 [==============================] - 0s 2ms/step - loss: 18041270173696.0000
# Epoch 9/50
# 1/1 [==============================] - 0s 2ms/step - loss: 713606064766976.0000
# Epoch 10/50
# 1/1 [==============================] - 0s 2ms/step - loss: 28226037590523904.0000
# Epoch 11/50
# 1/1 [==============================] - 0s 2ms/step - loss: 1116455308118458368.0000
# ...

# %%
print(modelo1.predict([25.0]))
# Out:
# [[nan nan nan nan]]
